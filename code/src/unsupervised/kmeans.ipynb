# %%
import pandas as pd
import numpy as np
import matplotlib
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.cluster import KMeans
import sys

sys.path.insert(1, 'C:/Users/ndelr/projects/Spotify-Top-200/code/src/preprocess/')
import preprocess

charts = preprocess.main()
charts.head(5)
# Out:
# Features:  ['danceability' 'energy' 'key' 'mode' 'loudness' 'speechiness'
#  'acousticness' 'instrumentalness' 'liveness' 'valence' 'tempo'
#  'tempo_name' 'duration_min']                                           track_name       artist_names  \
# 0                                     'Til You Can't       Cody Johnson
# 1                                   'Till I Collapse  Eminem, Nate Dogg
# 2                            (Don't Fear) The Reaper   Blue Öyster Cult
# 3  (Everybody's Waitin' For) The Man With The Bag...          Kay Starr
# 4  (There's No Place Like) Home for the Holidays ...         Perry Como
#
#    danceability  energy  key  mode  loudness  speechiness  acousticness  \
# 0         0.501   0.815  1.0   1.0  0.858052       0.0436        0.0513
# 1         0.548   0.847  1.0   1.0  0.911176       0.1860        0.0622
# 2         0.333   0.927  9.0   0.0  0.737804       0.0733        0.0029
# 3         0.739   0.317  0.0   1.0  0.733953       0.0905        0.3910
# 4         0.478   0.341  5.0   1.0  0.607081       0.0511        0.8970
#
#    instrumentalness  liveness  valence     tempo  tempo_name  duration_min
# 0          0.000000    0.1060    0.460  0.710372           5      0.286447
# 1          0.000000    0.0816    0.100  0.777751           5      0.398980
# 2          0.000208    0.2970    0.385  0.599926           4      0.414785
# 3          0.004870    0.2430    0.806  0.182955           1      0.191861
# 4          0.000000    0.2580    0.474  0.613390           4      0.212540
#                                           track_name       artist_names  \
# 0                                     'Til You Can't       Cody Johnson
# 1                                   'Till I Collapse  Eminem, Nate Dogg
# 2                            (Don't Fear) The Reaper   Blue Öyster Cult
# 3  (Everybody's Waitin' For) The Man With The Bag...          Kay Starr
# 4  (There's No Place Like) Home for the Holidays ...         Perry Como
#
#    danceability  energy  key  mode  loudness  speechiness  acousticness  \
# 0         0.501   0.815  1.0   1.0  0.858052       0.0436        0.0513
# 1         0.548   0.847  1.0   1.0  0.911176       0.1860        0.0622
# 2         0.333   0.927  9.0   0.0  0.737804       0.0733        0.0029
# 3         0.739   0.317  0.0   1.0  0.733953       0.0905        0.3910
# 4         0.478   0.341  5.0   1.0  0.607081       0.0511        0.8970
#
#    instrumentalness  liveness  valence     tempo  tempo_name  duration_min
# 0          0.000000    0.1060    0.460  0.710372           5      0.286447
# 1          0.000000    0.0816    0.100  0.777751           5      0.398980
# 2          0.000208    0.2970    0.385  0.599926           4      0.414785
# 3          0.004870    0.2430    0.806  0.182955           1      0.191861
# 4          0.000000    0.2580    0.474  0.613390           4      0.212540

# %% [markdown]
# K-Means Clustering
